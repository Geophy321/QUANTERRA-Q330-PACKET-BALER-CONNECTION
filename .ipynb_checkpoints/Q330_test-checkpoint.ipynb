# %% [markdown]
# OBJECTIVE: Communication with BALER and Prelimiary data analysis,
# STEPS: Change the IP adress of PC, change to flight mode. Open BALER, add the IP adress of PC in BALER. If PC IP= 192.168.2.10, the IP of BALER will be IP= 192.168.2.11
# COMMENTS: Sytem worked fine. Data recodings have no earthquakes,
# RECOMMENDATIONS: For future use we have to configure it based on the objectives.

# %%
ls
# Out:
#  DT0001__.HHE*   DT0001__.HLE*  'Non confermato 443208.crdownload'*
#  DT0001__.HHN*   DT0001__.HLN*   Q330_test.ipynb*
#  DT0001__.HHZ*   DT0001__.HLZ*   Qt.CIAO.txt*

# %%
st=read('DT0001__.HHE')
tr=st[0]
for tr in st:
        print(tr);
# Out:
# QT.CIAO..HHE | 2021-12-23T12:03:29.574538Z - 2021-12-23T12:04:46.979538Z | 200.0 Hz, 15482 samples
# QT.CIAO..HHE | 2021-12-23T12:04:48.984548Z - 2021-12-23T12:06:19.784548Z | 200.0 Hz, 18161 samples
# QT.CIAO..HHE | 2022-05-23T10:49:13.984542Z - 2022-05-23T10:50:44.914542Z | 200.0 Hz, 18187 samples
# QT.CIAO..HHE | 2022-05-23T11:03:54.379541Z - 2022-05-23T11:04:55.979541Z | 200.0 Hz, 12321 samples
# QT.CIAO..HHE | 2022-05-30T09:17:56.984538Z - 2022-05-30T09:19:59.089538Z | 200.0 Hz, 24422 samples
# QT.CIAO..HHE | 2022-05-30T09:22:35.299538Z - 2022-05-30T09:26:18.254538Z | 200.0 Hz, 44592 samples
# QT.CIAO..HHE | 2022-05-30T09:29:49.419538Z - 2022-05-30T09:32:50.809538Z | 200.0 Hz, 36279 samples
# QT.CIAO..HHE | 2022-05-30T09:40:01.964538Z - 2022-05-30T09:44:08.004538Z | 200.0 Hz, 49209 samples
# QT.CIAO..HHE | 2022-05-30T09:54:13.394539Z - 2022-05-30T09:57:36.124539Z | 200.0 Hz, 40547 samples
# ...

# %%
print(tr.stats);
# Out:
#          network: QT
#          station: CIAO
#         location:
#          channel: HHE
#        starttime: 2023-02-09T16:31:35.044538Z
#          endtime: 2023-02-09T16:33:29.979538Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 22988
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 6, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 4096, 'filesize': 749568})

# %%
for tr in st:
        tr.plot();

# %%
for tr in st:
        tr.detrend()
        tr.plot();
